# %% [markdown]
# Importamos las librerías necesarias

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
from nltk.corpus import stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /home/ordovas/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/ordovas/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ordovas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Empezamos el entrenamiento

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!','¿','¡',',']+stopwords.words('spanish')
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 46 documents
# 6 classes ['goodbye', 'greetings', 'i_have_sympthoms', 'list_synthoms', 'thanks', 'whatiscovid']
# 79 unique lemmatized words ['adios', 'agradecido', 'alguien', 'ase', 'buenas', 'buenos', 'chat', 'ciao', 'cierro', 'cogido', 'concha', 'contagiado', 'coronabirus', 'coronavirus', 'cosas', 'covid', 'covid-19', 'covid19', 'creo', 'cómo', 'dame', 'dar', 'debe', 'debo', 'dime', 'días', 'enseñame', 'entro', 'esto', 'eternamente', 'explicame', 'ey', 'fiebre', 'gracias', 'ha', 'hablar', 'hasta', 'hazme', 'hola', 'holi', 'hospital', 'infectado', 'info', 'informacion', 'información', 'ir', 'ke', 'lista', 'llamar', 'luego', 'me', 'muchas', 'muestrame', 'médico', 'no', 'ola', 'provoca', 'puedas', 'quería', 'saber', 'sars-cov-2', 'sarscov2', 'si', 'sido', 'sintomas', 'sintomatología', 'soy', 'síntomas', 'tardes', 'tengo', 'toda', 'tos', 'vemos', 'voy', '¡hola', '¿cuáles', '¿cómo', '¿qué', 'útil']

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# <ipython-input-5-1a891a7a8859>:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.7601 - accuracy: 0.2826
# Epoch 2/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.7105 - accuracy: 0.1957
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7087 - accuracy: 0.3043
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.6036 - accuracy: 0.3696
# Epoch 5/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.5567 - accuracy: 0.4348
# Epoch 6/200
# 10/10 [==============================] - 0s 9ms/step - loss: 1.5206 - accuracy: 0.3261
# Epoch 7/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4926 - accuracy: 0.3478
# Epoch 8/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.3632 - accuracy: 0.4783
# Epoch 9/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1994 - accuracy: 0.6304
# Epoch 10/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1355 - accuracy: 0.6087
# Epoch 11/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0249 - accuracy: 0.6304
# Epoch 12/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.0232 - accuracy: 0.6087
# Epoch 13/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.9039 - accuracy: 0.7174
# Epoch 14/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7307 - accuracy: 0.7609
# Epoch 15/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6851 - accuracy: 0.7609
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7494 - accuracy: 0.7826
# Epoch 17/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5800 - accuracy: 0.8913
# Epoch 18/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6209 - accuracy: 0.8043
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5481 - accuracy: 0.8696
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4626 - accuracy: 0.8696
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4338 - accuracy: 0.9130
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4952 - accuracy: 0.8478
# Epoch 23/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3223 - accuracy: 0.9348
# Epoch 24/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3581 - accuracy: 0.9348
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2591 - accuracy: 0.9783
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3209 - accuracy: 0.9130
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2525 - accuracy: 0.9348
# Epoch 28/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2009 - accuracy: 0.9783
# Epoch 29/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2516 - accuracy: 0.9565
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2282 - accuracy: 0.9783
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1832 - accuracy: 0.9783
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1541 - accuracy: 0.9565
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 0.9348
# Epoch 34/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1262 - accuracy: 0.9783
# Epoch 35/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1187 - accuracy: 0.9565
# Epoch 36/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1785 - accuracy: 0.9783
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1666 - accuracy: 0.9565
# Epoch 38/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2154 - accuracy: 0.9348
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 0.9783
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0901 - accuracy: 1.0000
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0677 - accuracy: 1.0000
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1380 - accuracy: 0.9783
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1988 - accuracy: 0.9348
# Epoch 44/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1747 - accuracy: 0.9565
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1005 - accuracy: 1.0000
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1426 - accuracy: 0.9348
# Epoch 47/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0623 - accuracy: 1.0000
# Epoch 48/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1351 - accuracy: 0.9783
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0801 - accuracy: 1.0000
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0506 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1388 - accuracy: 0.9783
# Epoch 53/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0772 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0770 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0840 - accuracy: 0.9783
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 1.0000
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.9565
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0786 - accuracy: 1.0000
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 60/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0739 - accuracy: 0.9783
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0603 - accuracy: 1.0000
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 0.9783
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0632 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0922 - accuracy: 0.9565
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1038 - accuracy: 0.9783
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 0.9783
# Epoch 69/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0574 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0683 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0491 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0589 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9783
# Epoch 76/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0463 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0594 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9565
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0705 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0471 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 0.9783
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0386 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0800 - accuracy: 0.9783
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0722 - accuracy: 0.9783
# Epoch 90/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0616 - accuracy: 0.9783
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0518 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0629 - accuracy: 0.9565
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0359 - accuracy: 0.9783
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0607 - accuracy: 0.9783
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0922 - accuracy: 0.9783
# Epoch 103/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0472 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0507 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9783
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 0.9783
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0891 - accuracy: 0.9783
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0451 - accuracy: 0.9783
# Epoch 121/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0344 - accuracy: 0.9783
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0506 - accuracy: 0.9783
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 889us/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0625 - accuracy: 0.9783
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0807 - accuracy: 0.9783
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 849us/step - loss: 0.0354 - accuracy: 0.9783
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0539 - accuracy: 0.9783
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 0.9783
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0488 - accuracy: 0.9783
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0869 - accuracy: 0.9783
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0516 - accuracy: 0.9783
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9783
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 0.9783
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0347 - accuracy: 0.9783
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 0.9783
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 0.9783
# Epoch 167/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 0.9783
# Epoch 170/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0601 - accuracy: 0.9783
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0360 - accuracy: 0.9783
# Epoch 179/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 1.0000
# model created

# %% [markdown]
# Funciones para hacer funcionar al chatbot

# %%
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %% [markdown]
# Chatbot GUI usando **tkinter**

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "Tú: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Chatbot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)


base = Tk()
base.title("Chatbot SARS")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="ENVIAR", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
